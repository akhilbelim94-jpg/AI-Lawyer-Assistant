# %%
print("I am the BEST")
# Out:
# I am the BEST

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader

def load_documents():
    document_loader = PyPDFDirectoryLoader(r"C:\Users\akhil\My_projects\ai_lawyer\data\books")
    return document_loader.load()

# %%
documents = load_documents()
print(documents[0].page_content[:50])
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 18 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Ignoring wrong pointing object 22 0 (offset 0)
# Ignoring wrong pointing object 24 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 28 0 (offset 0)
# Ignoring wrong pointing object 35 0 (offset 0)
# Ignoring wrong pointing object 37 0 (offset 0)
# Ignoring wrong pointing object 39 0 (offset 0)
# Ignoring wrong pointing object 41 0 (offset 0)
# Ignoring wrong pointing object 43 0 (offset 0)
# Ignoring wrong pointing object 45 0 (offset 0)
# Ignoring wrong pointing object 47 0 (offset 0)
# Ignoring wrong pointing object 52 0 (offset 0)
# Ignoring wrong pointing object 54 0 (offset 0)
# Ignoring wrong pointing object 56 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# Ignoring wrong pointing object 63 0 (offset 0)
# Ignoring wrong pointing object 65 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 74 0 (offset 0)
# Ignoring wrong pointing object 79 0 (offset 0)
# Ignoring wrong pointing object 84 0 (offset 0)
# Ignoring wrong pointing object 86 0 (offset 0)
# Ignoring wrong pointing object 88 0 (offset 0)
# Ignoring wrong pointing object 93 0 (offset 0)
# Ignoring wrong pointing object 102 0 (offset 0)
# Ignoring wrong pointing object 104 0 (offset 0)
# Ignoring wrong pointing object 106 0 (offset 0)
# Ignoring wrong pointing object 111 0 (offset 0)
# Ignoring wrong pointing object 116 0 (offset 0)
# Ignoring wrong pointing object 152 0 (offset 0)
# Ignoring wrong pointing object 223 0 (offset 0)
# Ignoring wrong pointing object 231 0 (offset 0)
# Ignoring wrong pointing object 240 0 (offset 0)
# Ignoring wrong pointing object 276 0 (offset 0)
# Ignoring wrong pointing object 278 0 (offset 0)
# Ignoring wrong pointing object 286 0 (offset 0)
# Ignoring wrong pointing object 288 0 (offset 0)
# Ignoring wrong pointing object 312 0 (offset 0)
# Ignoring wrong pointing object 564 0 (offset 0)
# Ignoring wrong pointing object 635 0 (offset 0)
# Ignoring wrong pointing object 649 0 (offset 0)
# Ignoring wrong pointing object 695 0 (offset 0)
# Ignoring wrong pointing object 757 0 (offset 0)
# Ignoring wrong pointing object 764 0 (offset 0)
# Ignoring wrong pointing object 831 0 (offset 0)
# Ignoring wrong pointing object 893 0 (offset 0)
# Ignoring wrong pointing object 1020 0 (offset 0)
# 1
# THE CODE OF CRIMINAL  PROCEDURE
# 1. The criminal

# %%
print("I am the Fucking No. 1")
# Out:
# I am the Fucking No. 1

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document

def split_documents(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=800,
        chunk_overlap=80,
        length_function=len,
        is_separator_regex=False,
    )
    return text_splitter.split_documents(documents)

# %%
documents = load_documents()
chunks = split_documents(documents)
print(chunks[0])
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 18 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Ignoring wrong pointing object 22 0 (offset 0)
# Ignoring wrong pointing object 24 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 28 0 (offset 0)
# Ignoring wrong pointing object 35 0 (offset 0)
# Ignoring wrong pointing object 37 0 (offset 0)
# Ignoring wrong pointing object 39 0 (offset 0)
# Ignoring wrong pointing object 41 0 (offset 0)
# Ignoring wrong pointing object 43 0 (offset 0)
# Ignoring wrong pointing object 45 0 (offset 0)
# Ignoring wrong pointing object 47 0 (offset 0)
# Ignoring wrong pointing object 52 0 (offset 0)
# Ignoring wrong pointing object 54 0 (offset 0)
# Ignoring wrong pointing object 56 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# Ignoring wrong pointing object 63 0 (offset 0)
# Ignoring wrong pointing object 65 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 74 0 (offset 0)
# Ignoring wrong pointing object 79 0 (offset 0)
# Ignoring wrong pointing object 84 0 (offset 0)
# Ignoring wrong pointing object 86 0 (offset 0)
# Ignoring wrong pointing object 88 0 (offset 0)
# Ignoring wrong pointing object 93 0 (offset 0)
# Ignoring wrong pointing object 102 0 (offset 0)
# Ignoring wrong pointing object 104 0 (offset 0)
# Ignoring wrong pointing object 106 0 (offset 0)
# Ignoring wrong pointing object 111 0 (offset 0)
# Ignoring wrong pointing object 116 0 (offset 0)
# Ignoring wrong pointing object 152 0 (offset 0)
# Ignoring wrong pointing object 223 0 (offset 0)
# Ignoring wrong pointing object 231 0 (offset 0)
# Ignoring wrong pointing object 240 0 (offset 0)
# Ignoring wrong pointing object 276 0 (offset 0)
# Ignoring wrong pointing object 278 0 (offset 0)
# Ignoring wrong pointing object 286 0 (offset 0)
# Ignoring wrong pointing object 288 0 (offset 0)
# Ignoring wrong pointing object 312 0 (offset 0)
# Ignoring wrong pointing object 564 0 (offset 0)
# Ignoring wrong pointing object 635 0 (offset 0)
# Ignoring wrong pointing object 649 0 (offset 0)
# Ignoring wrong pointing object 695 0 (offset 0)
# Ignoring wrong pointing object 757 0 (offset 0)
# Ignoring wrong pointing object 764 0 (offset 0)
# Ignoring wrong pointing object 831 0 (offset 0)
# Ignoring wrong pointing object 893 0 (offset 0)
# Ignoring wrong pointing object 1020 0 (offset 0)
# page_content='1
# THE CODE OF CRIMINAL  PROCEDURE
# 1. The criminal procedure code is both substantive &
# procedural in nature.
# Law is a popular term. It is very difficult to give a
# uniform and precise definition of law. Law has been
# defined differently by different jurists. The Government
# prescribes a certain uniformity of human action to be
# followed by the subjects in day to day  for the welfare &
# progress of the people & the society.
# That is known as law. The duly of the stare  is many fold
# out of which maintenance of peace in the society and
# administration of justice are  important. Function of law is
# to maintain law and order in the society and that people
# can live in peace and pursue their respective goals.
# Without law people can never be able to live in peace and' metadata={'producer': 'Nitro Pro 8  (8. 5. 5. 2)', 'creator': 'Nitro Pro', 'creationdate': '2015-05-01T06:23:37+00:00', 'moddate': '2015-05-01T02:25:21-04:00', 'author': 'User', 'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\2023121818.pdf', 'total_pages': 117, 'page': 0, 'page_label': '1'}

# %%
print(chunks[50])
# Out:
# page_content='arrestee and the police officer and a copy of it must be
# given to the arrestee.
# 8. Arrestee should be subject to medical examination at
# every 48 hours of his detention by a doctor whose name' metadata={'producer': 'Nitro Pro 8  (8. 5. 5. 2)', 'creator': 'Nitro Pro', 'creationdate': '2015-05-01T06:23:37+00:00', 'moddate': '2015-05-01T02:25:21-04:00', 'author': 'User', 'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\2023121818.pdf', 'total_pages': 117, 'page': 21, 'page_label': '22'}

# %%
from langchain_community.embeddings.ollama import OllamaEmbeddings

def get_embedding_function():
    embeddings = OllamaEmbeddings(model="nomic-embed-text")
    return embeddings

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\akhil\My_projects\ai_lawyer\venv\Scripts\python.exe

# %%
import sys
# !{sys.executable} -m pip show langchain-ollama
# Out:
# Name: langchain-ollama
# Version: 1.1.0
# Summary: An integration package connecting Ollama and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/ollama
# Author:
# Author-email:
# License: MIT
# Location: c:\users\akhil\my_projects\ai_lawyer\venv\lib\site-packages
# Requires: langchain-core, ollama
# Required-by:

# %%
from get_embedding_function import get_embedding_function

embeddings = get_embedding_function()
print(len(embeddings.embed_query("hello")))
# Out:
# 768

# %%
from langchain_chroma import Chroma
print("OK")
# Out:
# OK

# %%
last_page_id = None
current_chunk_index = 0

for chunk in chunks:
    # Get source and page number
    source = chunk.metadata.get("source")
    page = chunk.metadata.get("page")

    # Create page identifier
    current_page_id = f"{source}:{page}"

    # Check if we're still on the same page
    if current_page_id == last_page_id:
        current_chunk_index += 1
    else:
        current_chunk_index = 0

    # Create unique chunk ID
    chunk_id = f"{current_page_id}:{current_chunk_index}"

    # Store ID in metadata
    chunk.metadata["id"] = chunk_id

    # Update last page ID
    last_page_id = current_page_id

# %%
for chunk in chunks[:5]:
    print(chunk.metadata["id"])
# Out:
# C:\Users\akhil\My_projects\ai_lawyer\data\books\2023121818.pdf:0:0
# C:\Users\akhil\My_projects\ai_lawyer\data\books\2023121818.pdf:0:1
# C:\Users\akhil\My_projects\ai_lawyer\data\books\2023121818.pdf:1:0
# C:\Users\akhil\My_projects\ai_lawyer\data\books\2023121818.pdf:1:1
# C:\Users\akhil\My_projects\ai_lawyer\data\books\2023121818.pdf:2:0

# %%
from langchain_chroma import Chroma
from langchain_core.documents import Document
from get_embedding_function import get_embedding_function

def add_to_chroma(chunks: list[Document]):
    db = Chroma(
        persist_directory="./chroma_db",
        embedding_function=get_embedding_function()
    )
    db.add_documents(chunks)

# %%
from langchain_core.documents import Document

docs = [
    Document(page_content="Section 420 IPC deals with cheating")
]

add_to_chroma(docs)
print("Stored successfully")
# Out:
# Stored successfully

# %%
from langchain_chroma import Chroma
from get_embedding_function import get_embedding_function

CHROMA_PATH = "./chroma_db"

db = Chroma(
    persist_directory=CHROMA_PATH,
    embedding_function=get_embedding_function()
)

# %%
print(type(db))
# Out:
# <class 'langchain_chroma.vectorstores.Chroma'>

# %%
existing_items = db.get(include=[])

existing_ids = set(existing_items["ids"])

print(f"Existing documents: {len(existing_ids)}")
# Out:
# Existing documents: 11736

# %%
new_chunks = []

for chunk in chunks:
    if chunk.metadata["id"] not in existing_ids:
        new_chunks.append(chunk)

print(f"New chunks: {len(new_chunks)}")
# Out:
# New chunks: 0

# %%
test_chunks = new_chunks[:5]

db.add_documents(
    test_chunks,
    ids=[chunk.metadata["id"] for chunk in test_chunks]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 test_chunks = new_chunks[:5]
# ----> 3 db.add_documents(
#       4     test_chunks,
#       5     ids=[chunk.metadata["id"] for chunk in test_chunks]
#       6 )
#
# File c:\Users\akhil\My_projects\ai_lawyer\venv\lib\site-packages\langchain_core\vectorstores\base.py:258, in VectorStore.add_documents(self, documents, **kwargs)
#     256     texts = [doc.page_content for doc in documents]
#     257     metadatas = [doc.metadata for doc in documents]
# --> 258     return self.add_texts(texts, metadatas, **kwargs)
#     259 msg = (
#     260     f"`add_documents` and `add_texts` has not been implemented "
#     261     f"for {self.__class__.__name__} "
#     262 )
#     263 raise NotImplementedError(msg)
#
# File c:\Users\akhil\My_projects\ai_lawyer\venv\lib\site-packages\langchain_chroma\vectorstores.py:677, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     671         self._collection.upsert(
#     672             embeddings=embeddings_without_metadatas,  # type: ignore[arg-type]
#     673             documents=texts_without_metadatas,
#     674             ids=ids_without_metadatas,
#     675         )
#     676 else:
# --> 677     self._collection.upsert(
#     678         embeddings=embeddings,  # type: ignore[arg-type]
#     679         documents=texts,
#     680         ids=ids,
#     681     )
#     682 return ids
#
# File c:\Users\akhil\My_projects\ai_lawyer\venv\lib\site-packages\chromadb\api\models\Collection.py:494, in Collection.upsert(self, ids, embeddings, metadatas, documents, images, uris)
#     470 def upsert(
#     471     self,
#     472     ids: OneOrMany[ID],
#    (...)
#     482     uris: Optional[OneOrMany[URI]] = None,
#     483 ) -> None:
#     484     """Create or update records by ID.
#     485
#     486     Args:
#    (...)
#     492         uris: URIs for loading images.
#     493     """
# --> 494     upsert_request = self._validate_and_prepare_upsert_request(
#     495         ids=ids,
#     496         embeddings=embeddings,
#     497         metadatas=metadatas,
#     498         documents=documents,
#     499         images=images,
#     500         uris=uris,
#     501     )
#     503     self._client._upsert(
#     504         collection_id=self.id,
#     505         ids=upsert_request["ids"],
#    (...)
#     511         database=self.database,
#     512     )
#
# File c:\Users\akhil\My_projects\ai_lawyer\venv\lib\site-packages\chromadb\api\models\CollectionCommon.py:103, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#     100 @functools.wraps(func)
#     101 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#     102     try:
# --> 103         return func(self, *args, **kwargs)
#     104     except Exception as e:
#     105         msg = f"{str(e)} in {name}."
#
# File c:\Users\akhil\My_projects\ai_lawyer\venv\lib\site-packages\chromadb\api\models\CollectionCommon.py:431, in CollectionCommon._validate_and_prepare_upsert_request(self, ids, embeddings, metadatas, documents, images, uris)
#     415 @validation_context("upsert")
#     416 def _validate_and_prepare_upsert_request(
#     417     self,
#    (...)
#     429 ) -> UpsertRequest:
#     430     # Unpack
# --> 431     upsert_records = normalize_insert_record_set(
#     432         ids=ids,
#     433         embeddings=embeddings,
#     434         metadatas=metadatas,
#     435         documents=documents,
#     436         images=images,
#     437         uris=uris,
#     438     )
#     440     # Validate
#     441     validate_insert_record_set(record_set=upsert_records)
#
# File c:\Users\akhil\My_projects\ai_lawyer\venv\lib\site-packages\chromadb\api\types.py:404, in normalize_insert_record_set(ids, embeddings, metadatas, documents, images, uris)
#     383 def normalize_insert_record_set(
#     384     ids: OneOrMany[ID],
#     385     embeddings: Optional[
#    (...)
#     394     uris: Optional[OneOrMany[URI]] = None,
#     395 ) -> InsertRecordSet:
#     396     """
#     397     Unpacks and normalizes the fields of an InsertRecordSet.
#     398
#    (...)
#     402     - Converting single values to lists where appropriate
#     403     """
# --> 404     base_record_set = normalize_base_record_set(
#     405         embeddings=embeddings, documents=documents, images=images, uris=uris
#     406     )
#     408     return InsertRecordSet(
#     409         ids=cast(IDs, maybe_cast_one_to_many(ids)),
#     410         metadatas=normalize_metadatas(metadatas),  # type: ignore[typeddict-item]
#    (...)
#     414         uris=base_record_set["uris"],
#     415     )
#
# File c:\Users\akhil\My_projects\ai_lawyer\venv\lib\site-packages\chromadb\api\types.py:376, in normalize_base_record_set(embeddings, documents, images, uris)
#     365 def normalize_base_record_set(
#     366     embeddings: Optional[Union[OneOrMany[Embedding], OneOrMany[PyEmbedding]]] = None,
#     367     documents: Optional[OneOrMany[Document]] = None,
#     368     images: Optional[OneOrMany[Image]] = None,
#     369     uris: Optional[OneOrMany[URI]] = None,
#     370 ) -> BaseRecordSet:
#     371     """
#     372     Unpacks and normalizes the fields of a BaseRecordSet.
#     373     """
#     375     return BaseRecordSet(
# --> 376         embeddings=normalize_embeddings(embeddings),
#     377         documents=maybe_cast_one_to_many(documents),
#     378         images=maybe_cast_one_to_many(images),
#     379         uris=maybe_cast_one_to_many(uris),
#     380     )
#
# File c:\Users\akhil\My_projects\ai_lawyer\venv\lib\site-packages\chromadb\api\types.py:230, in normalize_embeddings(target)
#     227     return None
#     229 if len(target) == 0:
# --> 230     raise ValueError(
#     231         f"Expected Embeddings to be non-empty list or numpy array, got {target}"
#     232     )
#     234 if isinstance(target, np.ndarray):
#     235     if target.ndim == 1:
#
# ValueError: Expected Embeddings to be non-empty list or numpy array, got [] in upsert.

# %%
print(len(documents))
print(len(chunks))
# Out:
# 2630
# 11728

# %%
BATCH_SIZE = 40

if len(new_chunks) == 0:
    print("No new documents to add.") 

else:
    total = len(new_chunks)

    for i in range(0, total, BATCH_SIZE):
        batch = new_chunks[i:i + BATCH_SIZE]

        db.add_documents(
            batch,
            ids=[chunk.metadata["id"] for chunk in batch]
        )

        print(f"Added {min(i + BATCH_SIZE, total)} / {total}")

    print("All documents added successfully!")
# Out:
# No new documents to add.

# %%
query = "What is Article 21?"

results = db.similarity_search(query, k=3)

results
# Out:
# [Document(id='C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\Ist Term_Family Law- I_LB105_2023.pdf:27:1', metadata={'producer': 'macOS Version 13.0.1 (Build 22A400) Quartz PDFContext', 'creationdate': "D:20230206054129Z00'00'", 'page': 27, 'moddate': "D:20230206054129Z00'00'", 'creator': 'Word', 'page_label': '28', 'title': '105 Family Law- I (2 files merged)', 'author': 'Dr.Arti Aneja', 'total_pages': 303, 'id': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\Ist Term_Family Law- I_LB105_2023.pdf:27:1', 'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\Ist Term_Family Law- I_LB105_2023.pdf'}, page_content='rights to be real or prima facie substantiated. 61. The alleged violation of Article 21 is misconceived. What is guaranteed under Article 21 is that no person shall be deprived of his life and personal liberty except according to the procedure established by law. It is conceded before us that actually and factually none of the petitioners has been deprived of any right of his life and personal liberty so far. The aggrieved persons are apprehended to be prosecuted for the commission of offence punishable under Section 494 IPC. It is premature, at this stage, to canvass that they would be deprived of their life and liberty without following the procedure established by law. The procedure established by law, as mentioned in Article 21 of the Constitution, means the law prescribed by the'),
#  Document(id='C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:136:3', metadata={'total_pages': 402, 'producer': 'iLovePDF', 'creator': 'PyPDF', 'moddate': '2024-07-01T11:20:33+00:00', 'creationdate': '', 'page_label': '137', 'id': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:136:3', 'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf', 'page': 136}, page_content='of article 131A," omitted by the Constitution (Forty-third Amendment) Act, 1977, s. 9 (w.e.f. 13-4-1978).'),
#  Document(id='C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:107:3', metadata={'moddate': '2024-07-01T11:20:33+00:00', 'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf', 'creationdate': '', 'producer': 'iLovePDF', 'page': 107, 'creator': 'PyPDF', 'id': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:107:3', 'total_pages': 402, 'page_label': '108'}, page_content='(Forty-second Amendment) Act, 1976, s. 29 (w.e.f. 3-1-1977).5. Subs. by the Constitution (Eighty-fourth Amendment) Act, 2001, s. 5, for certain words (w.e.f. 21-2-2002).')]

# %%
for result in results:
    print(result.page_content)
    print("-" * 100)
# Out:
# rights to be real or prima facie substantiated. 61. The alleged violation of Article 21 is misconceived. What is guaranteed under Article 21 is that no person shall be deprived of his life and personal liberty except according to the procedure established by law. It is conceded before us that actually and factually none of the petitioners has been deprived of any right of his life and personal liberty so far. The aggrieved persons are apprehended to be prosecuted for the commission of offence punishable under Section 494 IPC. It is premature, at this stage, to canvass that they would be deprived of their life and liberty without following the procedure established by law. The procedure established by law, as mentioned in Article 21 of the Constitution, means the law prescribed by the
# ----------------------------------------------------------------------------------------------------
# of article 131A," omitted by the Constitution (Forty-third Amendment) Act, 1977, s. 9 (w.e.f. 13-4-1978).
# ----------------------------------------------------------------------------------------------------
# (Forty-second Amendment) Act, 1976, s. 29 (w.e.f. 3-1-1977).5. Subs. by the Constitution (Eighty-fourth Amendment) Act, 2001, s. 5, for certain words (w.e.f. 21-2-2002).
# ----------------------------------------------------------------------------------------------------

# %%
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import OllamaLLM

from get_embedding_function import get_embedding_function

# %%
CHROMA_PATH = "chroma_db"

db = Chroma(
    persist_directory=CHROMA_PATH,
    embedding_function=get_embedding_function()
)

# %%
query_text = "What is Article 21?"

# %%
results = db.similarity_search_with_score(query_text, k=5)

results
# Out:
# [(Document(id='C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\Ist Term_Family Law- I_LB105_2023.pdf:27:1', metadata={'creator': 'Word', 'total_pages': 303, 'title': '105 Family Law- I (2 files merged)', 'producer': 'macOS Version 13.0.1 (Build 22A400) Quartz PDFContext', 'id': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\Ist Term_Family Law- I_LB105_2023.pdf:27:1', 'page': 27, 'creationdate': "D:20230206054129Z00'00'", 'moddate': "D:20230206054129Z00'00'", 'page_label': '28', 'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\Ist Term_Family Law- I_LB105_2023.pdf', 'author': 'Dr.Arti Aneja'}, page_content='rights to be real or prima facie substantiated. 61. The alleged violation of Article 21 is misconceived. What is guaranteed under Article 21 is that no person shall be deprived of his life and personal liberty except according to the procedure established by law. It is conceded before us that actually and factually none of the petitioners has been deprived of any right of his life and personal liberty so far. The aggrieved persons are apprehended to be prosecuted for the commission of offence punishable under Section 494 IPC. It is premature, at this stage, to canvass that they would be deprived of their life and liberty without following the procedure established by law. The procedure established by law, as mentioned in Article 21 of the Constitution, means the law prescribed by the'),
#   0.6090325713157654),
#  (Document(id='C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:136:3', metadata={'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf', 'creationdate': '', 'creator': 'PyPDF', 'producer': 'iLovePDF', 'moddate': '2024-07-01T11:20:33+00:00', 'page': 136, 'page_label': '137', 'total_pages': 402, 'id': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:136:3'}, page_content='of article 131A," omitted by the Constitution (Forty-third Amendment) Act, 1977, s. 9 (w.e.f. 13-4-1978).'),
#   0.7383131980895996),
#  (Document(id='C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:107:3', metadata={'producer': 'iLovePDF', 'page_label': '108', 'creationdate': '', 'creator': 'PyPDF', 'page': 107, 'moddate': '2024-07-01T11:20:33+00:00', 'total_pages': 402, 'id': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:107:3', 'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf'}, page_content='(Forty-second Amendment) Act, 1976, s. 29 (w.e.f. 3-1-1977).5. Subs. by the Constitution (Eighty-fourth Amendment) Act, 2001, s. 5, for certain words (w.e.f. 21-2-2002).'),
#   0.739601731300354),
#  (Document(id='C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\constitution_of_india.pdf:17:2', metadata={'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\constitution_of_india.pdf', 'moddate': '2009-01-07T10:38:38+05:30', 'total_pages': 268, 'page': 17, 'producer': 'Acrobat Distiller 7.0 (Windows)', 'creator': 'PageMaker 7.0', 'title': 'Law & Justice2.pmd', 'page_label': '18', 'id': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\constitution_of_india.pdf:17:2', 'author': 'winxp', 'creationdate': '2009-01-07T10:38:10+05:30'}, page_content='considered in proceedings under article  32.] Rep. by the\nConstitution (Forty-third Amendment) Act, 1977, s. 3 ( w.e.f.\n13-4-1978).\nRemedies for\nenforcement of\nrights conferred by\nthis Part.\n1Ins. by the Constitution (Forty-second Amendment) Act, 1976, s. 5 (w.e.f.  3-1-1977).\n2Ins. by s. 6, ibid.  (w.e.f. 1-2-1977).\nTHE CONSTITUTION OF INDIA\n(Part III.—Fundamental Rights.—Arts. 31C—32A.)\n18'),
#   0.7586709260940552),
#  (Document(id='C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:115:3', metadata={'source': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf', 'page': 115, 'creator': 'PyPDF', 'total_pages': 402, 'page_label': '116', 'moddate': '2024-07-01T11:20:33+00:00', 'producer': 'iLovePDF', 'id': 'C:\\Users\\akhil\\My_projects\\ai_lawyer\\data\\books\\20240716890312078.pdf:115:3', 'creationdate': ''}, page_content='the Constitution (Fifty-second Amendment) Act, 1985, s. 4, for "clause (1) of article 191" (w.e.f. 1-3-1985).3 Subs. by the Constitution (Thirty-third Amendment) Act, 1974, s. 3 (w.e.f. 19-5-1974).4. Ins. by s. 3, ibid.(w.e.f. 19-5-1974).'),
#   0.7640255093574524)]

# %%
PROMPT_TEMPLATE = """
Answer the question based only on the following context:

{context}

---

Answer the question based on the above context:

{question}
"""

# %%
context_text = "\n\n---\n\n".join(
    [doc.page_content for doc, _score in results]
)

# %%
prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)

prompt = prompt_template.format(
    context=context_text,
    question=query_text
)

print(prompt)
# Out:
# Human:
# Answer the question based only on the following context:
#
# rights to be real or prima facie substantiated. 61. The alleged violation of Article 21 is misconceived. What is guaranteed under Article 21 is that no person shall be deprived of his life and personal liberty except according to the procedure established by law. It is conceded before us that actually and factually none of the petitioners has been deprived of any right of his life and personal liberty so far. The aggrieved persons are apprehended to be prosecuted for the commission of offence punishable under Section 494 IPC. It is premature, at this stage, to canvass that they would be deprived of their life and liberty without following the procedure established by law. The procedure established by law, as mentioned in Article 21 of the Constitution, means the law prescribed by the
#
# ---
#
# of article 131A," omitted by the Constitution (Forty-third Amendment) Act, 1977, s. 9 (w.e.f. 13-4-1978).
#
# ---
#
# (Forty-second Amendment) Act, 1976, s. 29 (w.e.f. 3-1-1977).5. Subs. by the Constitution (Eighty-fourth Amendment) Act, 2001, s. 5, for certain words (w.e.f. 21-2-2002).
#
# ---
#
# considered in proceedings under article  32.] Rep. by the
# Constitution (Forty-third Amendment) Act, 1977, s. 3 ( w.e.f.
# 13-4-1978).
# Remedies for
# enforcement of
# rights conferred by
# this Part.
# 1Ins. by the Constitution (Forty-second Amendment) Act, 1976, s. 5 (w.e.f.  3-1-1977).
# 2Ins. by s. 6, ibid.  (w.e.f. 1-2-1977).
# THE CONSTITUTION OF INDIA
# (Part III.—Fundamental Rights.—Arts. 31C—32A.)
# 18
#
# ---
#
# the Constitution (Fifty-second Amendment) Act, 1985, s. 4, for "clause (1) of article 191" (w.e.f. 1-3-1985).3 Subs. by the Constitution (Thirty-third Amendment) Act, 1974, s. 3 (w.e.f. 19-5-1974).4. Ins. by s. 3, ibid.(w.e.f. 19-5-1974).
#
# ---
#
# Answer the question based on the above context:
#
# What is Article 21?

# %%
model = OllamaLLM(model="llama3.2")

# %%
response_text = model.invoke(prompt)

print(response_text)
# Out:
# Article 21 guarantees that no person shall be deprived of his life and personal liberty except according to the procedure established by law.

# %%
sources = [
    doc.metadata.get("id", None)
    for doc, _score in results
]

print("Sources:")

for source in sources:
    print(source)
# Out:
# Sources:
# C:\Users\akhil\My_projects\ai_lawyer\data\books\Ist Term_Family Law- I_LB105_2023.pdf:27:1
# C:\Users\akhil\My_projects\ai_lawyer\data\books\20240716890312078.pdf:136:3
# C:\Users\akhil\My_projects\ai_lawyer\data\books\20240716890312078.pdf:107:3
# C:\Users\akhil\My_projects\ai_lawyer\data\books\constitution_of_india.pdf:17:2
# C:\Users\akhil\My_projects\ai_lawyer\data\books\20240716890312078.pdf:115:3

# %%
query = "What are Fundamental Rights?"

results = db.similarity_search(query, k=3)

for i, doc in enumerate(results, start=1):
    print(f"Result {i}")
    print(doc.page_content[:500])
    print("-" * 80)
# Out:
# Result 1
# PART III FUNDAMENTAL RIGHTSGeneral12. Definition.—In this Part, unless the context otherwise requires, “the State” includes the Government and Parliament of India and the Government and the Legislature of each of the States and all local or other authorities within the territory of India or under the control of the Government of India.13. Laws inconsistent with or in derogation of the fundamental rights.—(1) All laws in force in the territory of India immediately before the commencement of this
# --------------------------------------------------------------------------------
# Result 2
# THE CONSTITUTION OF  INDIA(Part III.—Fundamental Rights)18(b) the expression “rights”, in relation to an estate, shall include any rights vesting in a proprietor, sub-proprietor, under-proprietor, tenure-holder, 1[raiyat, under-raiyat] or other intermediary and any rights or privileges in respect of land revenue.] 2[31B. Validation of certain Acts and Regulations.—Without prejudice to the generality of the provisions contained in article 31A, none of the Acts and Regulations specified in the Nin
# --------------------------------------------------------------------------------
# Result 3
# THE CONSTITUTION OF  INDIA(Part III.—Fundamental Rights)11(6) Nothing in sub-clause (g) of the said clause shall affect the operation of any existing law in so far as it imposes, or prevent the State from making any law imposing, in the interests of the general public, reasonable restrictions on the exercise of the right conferred by the said sub-clause, and, in particular, 1[nothing in the said sub-clause shall affect the operation of any existing law in so far as it relates to, or prevent the
# --------------------------------------------------------------------------------

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import OllamaLLM

# %%
PROMPT_TEMPLATE = """
You are an AI Legal Assistant.

Answer the user's question ONLY using the context below.

If the answer cannot be found in the context, reply:

"I couldn't find the answer in the provided legal documents."

Context:
{context}

--------------------------------

Question:
{question}

--------------------------------

Answer:
"""

# %%
query = "What is Article 21?"

# %%
results = db.max_marginal_relevance_search(
    query,
    k=3,
    fetch_k=10
)

# %%
context = "\n\n----------------------------\n\n".join(
    [doc.page_content for doc in results]
)

# %%
prompt_template = ChatPromptTemplate.from_template(
    PROMPT_TEMPLATE
)

prompt = prompt_template.format(
    context=context,
    question=query
)

print(prompt[:1500])
# Out:
# Human:
# You are an AI Legal Assistant.
#
# Answer the user's question ONLY using the context below.
#
# If the answer cannot be found in the context, reply:
#
# "I couldn't find the answer in the provided legal documents."
#
# Context:
# rights to be real or prima facie substantiated. 61. The alleged violation of Article 21 is misconceived. What is guaranteed under Article 21 is that no person shall be deprived of his life and personal liberty except according to the procedure established by law. It is conceded before us that actually and factually none of the petitioners has been deprived of any right of his life and personal liberty so far. The aggrieved persons are apprehended to be prosecuted for the commission of offence punishable under Section 494 IPC. It is premature, at this stage, to canvass that they would be deprived of their life and liberty without following the procedure established by law. The procedure established by law, as mentioned in Article 21 of the Constitution, means the law prescribed by the
#
# ----------------------------
#
# of article 131A," omitted by the Constitution (Forty-third Amendment) Act, 1977, s. 9 (w.e.f. 13-4-1978).
#
# ----------------------------
#
# 1. Subs. by Act 21 of 1929, s. 8 and Sch., for Forms 3 to 11.
# * Words not required to be deleted.
#
# --------------------------------
#
# Question:
# What is Article 21?
#
# --------------------------------
#
# Answer:

# %%
model = OllamaLLM(
    model="llama3.2"
)

# %%
response = model.invoke(prompt)

print(response)
# Out:
# Article 21 guarantees that no person shall be deprived of his life and personal liberty except according to the procedure established by law, as prescribed by the law mentioned in article 131A of the Constitution.
